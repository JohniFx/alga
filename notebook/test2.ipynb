# %%
import v20
import defs
import analyser
# Out:
# defs imported

# %%
ctx = v20.Context(hostname=defs.HOSTNAME, token=defs.key)
ctx.set_header(key='Authorization', value=defs.key)
a = analyser.Analyser(ctx)
a

# %%
ctx.account.

# %%
# óránként leszedjen 100 x M5 adatot;
# kiszámolja a linreg-et és a slope-t
# lementi jsonba; 
# mindezt annyi párra ami a defs. instruments-ben meg van határozba
# óránként ütemezni
# az analyzer ezt olvassa be.
# Out:
# 8.333333333333334

# %%
df = a.get_candles('EUR_USD')
df
# Out:
#     complete  volume    mid_o    mid_h    mid_l    mid_c    bid_o    bid_h  \
# 0       True     219  1.15964  1.15980  1.15954  1.15980  1.15957  1.15973
# 1       True     283  1.15978  1.15990  1.15972  1.15989  1.15971  1.15984
# 2       True     228  1.15987  1.16024  1.15982  1.16024  1.15980  1.16017
# 3       True     163  1.16025  1.16026  1.16008  1.16024  1.16018  1.16019
# 4       True     199  1.16022  1.16026  1.16011  1.16024  1.16015  1.16019
# 5       True     321  1.16022  1.16066  1.16022  1.16049  1.16016  1.16059
# 6       True     440  1.16048  1.16060  1.16036  1.16059  1.16041  1.16053
# 7       True     446  1.16058  1.16063  1.16026  1.16038  1.16050  1.16056
# 8       True     228  1.16037  1.16066  1.16028  1.16063  1.16030  1.16059
# 9       True     266  1.16065  1.16076  1.16062  1.16071  1.16058  1.16070
# 10      True     318  1.16069  1.16080  1.16060  1.16062  1.16062  1.16074
# ...
